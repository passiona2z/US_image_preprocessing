# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import urllib
import sys

import glob

# %% [markdown]
# ### BUSI

# %%
li = glob.glob('/dshome/ddualab/seonjin2/denosing/report/sample/BUSI')

img_list = []

for i in li :
    
    img = glob.glob(i + '/*.png')
    img_list.extend(img)

# %%
img_list
# Out:
# ['/dshome/ddualab/seonjin2/denosing/report/sample/BUSI/benign (108).png',
#  '/dshome/ddualab/seonjin2/denosing/report/sample/BUSI/malignant (71).png',
#  '/dshome/ddualab/seonjin2/denosing/report/sample/BUSI/malignant (127).png',
#  '/dshome/ddualab/seonjin2/denosing/report/sample/BUSI/normal (27).png',
#  '/dshome/ddualab/seonjin2/denosing/report/sample/BUSI/normal (132).png']

# %%
plt.figure(figsize=(12,6))

for i, img in enumerate(img_list):
  # 원본 흑백 이미지 로드
  img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
  resized_img = cv2.resize(img, (256, 256))
  
  
  plt.subplot(1, 5, i+1)
  plt.imshow(resized_img, cmap='gray')


  plt.xticks([])
  plt.yticks([])

# %%
plt.figure(figsize=(12,6))

for i, img in enumerate(img_list):
  # 원본 흑백 이미지 로드
  img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
  resized_img = cv2.resize(img, (256, 256))
  
  
  dst = cv2.equalizeHist(resized_img)
  
  
  
  plt.subplot(1, 5, i+1)
  plt.imshow(dst, cmap='gray')


  plt.xticks([])
  plt.yticks([])

# %% [markdown]
# ### B

# %%
li = glob.glob('/dshome/ddualab/seonjin2/denosing/report/sample/Dataset B')

img_list = []

for i in li :
    
    img = glob.glob(i + '/*.png')
    img_list.extend(img)

# %%
plt.figure(figsize=(12,6))

for i, img in enumerate(img_list):
  # 원본 흑백 이미지 로드
  img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
  resized_img = cv2.resize(img, (256, 256))
  
  
  plt.subplot(1, 5, i+1)
  plt.imshow(resized_img, cmap='gray')


  plt.xticks([])
  plt.yticks([])

# %%
plt.figure(figsize=(12,6))

for i, img in enumerate(img_list):
  # 원본 흑백 이미지 로드
  img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
  resized_img = cv2.resize(img, (256, 256))
  
  
  dst = cv2.equalizeHist(resized_img)
  
  
  
  plt.subplot(1, 5, i+1)
  plt.imshow(dst, cmap='gray')


  plt.xticks([])
  plt.yticks([])

# %% [markdown]
# ### NEW dataset

# %%
li = glob.glob('/dshome/ddualab/seonjin2/denosing/report/sample/Miccai BUV')

img_list = []

for i in li :
    
    img = glob.glob(i + '/*.png')
    img_list.extend(img)

# %%
plt.figure(figsize=(12,6))

for i, img in enumerate(img_list):
  # 원본 흑백 이미지 로드
  img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
  resized_img = cv2.resize(img, (256, 256))
  
  
  plt.subplot(1, 5, i+1)
  plt.imshow(resized_img, cmap='gray')


  plt.xticks([])
  plt.yticks([])

# %%
plt.figure(figsize=(12,6))

for i, img in enumerate(img_list):
  # 원본 흑백 이미지 로드
  img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
  resized_img = cv2.resize(img, (256, 256))
  
  
  dst = cv2.equalizeHist(resized_img)
  
  
  
  plt.subplot(1, 5, i+1)
  plt.imshow(dst, cmap='gray')


  plt.xticks([])
  plt.yticks([])

# %% [markdown]
# ### fatty liver

# %%
li = glob.glob('/dshome/ddualab/seonjin2/denosing/report/sample/fatty liver')

img_list = []

for i in li :
    
    img = glob.glob(i + '/*.png')
    img_list.extend(img)

# %%
plt.figure(figsize=(12,6))

for i, img in enumerate(img_list):
  # 원본 흑백 이미지 로드
  img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
  resized_img = cv2.resize(img, (256, 256))
  
  
  plt.subplot(1, 5, i+1)
  plt.imshow(resized_img, cmap='gray')


  plt.xticks([])
  plt.yticks([])

# %%
plt.figure(figsize=(12,6))

for i, img in enumerate(img_list):
  # 원본 흑백 이미지 로드
  img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
  resized_img = cv2.resize(img, (256, 256))
  
  
  dst = cv2.equalizeHist(resized_img)
  
  
  
  plt.subplot(1, 5, i+1)
  plt.imshow(dst, cmap='gray')


  plt.xticks([])
  plt.yticks([])

# %% [markdown]
# ### Kidney

# %%
li = glob.glob('/dshome/ddualab/seonjin2/denosing/report/sample/kidneyUS')

img_list = []

for i in li :
    
    img = glob.glob(i + '/*.png')
    img_list.extend(img)

# %%
plt.figure(figsize=(12,6))

for i, img in enumerate(img_list):
  # 원본 흑백 이미지 로드
  img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
  resized_img = cv2.resize(img, (256, 256))
  
  
  plt.subplot(1, 5, i+1)
  plt.imshow(resized_img, cmap='gray')


  plt.xticks([])
  plt.yticks([])

# %%
plt.figure(figsize=(12,6))

for i, img in enumerate(img_list):
  # 원본 흑백 이미지 로드
  img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
  resized_img = cv2.resize(img, (256, 256))
  
  
  dst = cv2.equalizeHist(resized_img)
  
  
  
  plt.subplot(1, 5, i+1)
  plt.imshow(dst, cmap='gray')


  plt.xticks([])
  plt.yticks([])

# %% [markdown]
# ## createCLAHE

# %%
plt.figure(figsize=(12,6))

for i, img in enumerate(img_list):
  # 원본 흑백 이미지 로드
  img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
  resized_img = cv2.resize(img, (256, 256))
  
  
  #dst = cv2.equalizeHist(resized_img)
  clahe = cv2.createCLAHE(clipLimit=42.0, tileGridSize=(8,8))
  dst = clahe.apply(resized_img)
  
  
  plt.subplot(1, 5, i+1)
  plt.imshow(dst, cmap='gray')


  plt.xticks([])
  plt.yticks([])
